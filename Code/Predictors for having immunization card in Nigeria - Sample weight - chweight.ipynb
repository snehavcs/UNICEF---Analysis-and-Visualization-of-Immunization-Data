# %% [markdown]
# # UNICEF MICS Survey data analysis

# %% [markdown]
# Understanding features that can predict why a caretaker might have a vaccination card using classification algorithms

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import  StandardScaler
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn import model_selection
from sklearn.utils import resample
from sklearn.metrics import classification_report

# %% [markdown]
# Data collected at the children's level (MICS Under Five Children's questionnaire modules: Under-five child information panel, Child's age, Birth registration, Early childhood development, Breastfeeding , Care of illness, Immunization, Under-five child selected for blood test.)
#
# Dataset produced by UNICEF and Central Statistics Organization

# %%
#importing ch.csv which was converted from .sav format in R. Check get_Congo_to_csv.R file
#Set low_memory = False to avoid the warning about column numbers having mixed type values.
## 100,104,106,114,115,116,117,118,120,122,123,125,126,127,131,133,134,136,152,153,168

ch_df = pd.read_csv('ch.csv',low_memory=False)

# %%
ch_df.describe()
# Out:
#          Unnamed: 0           HH1           HH2            LN           UF1  \
# count  26018.000000  26018.000000  26018.000000  26018.000000  26018.000000
# mean   13009.500000    765.843147     10.391959      6.122108    765.843147
# std     7510.893988    429.034000      5.756146      3.017196    429.034000
# min        1.000000      1.000000      1.000000      2.000000      1.000000
# 25%     6505.250000    394.000000      5.000000      4.000000    394.000000
# 50%    13009.500000    764.000000     10.000000      5.000000    764.000000
# 75%    19513.750000   1138.000000     15.000000      7.000000   1138.000000
# max    26018.000000   1480.000000     20.000000     41.000000   1480.000000
#
#                 UF2           UF4           UF6           UF7          UF8D  \
# count  26018.000000  26018.000000  26018.000000  26018.000000  26018.000000
# mean      10.391959      6.122108      2.889423     11.521255     14.596164
# std        5.756146      3.017196      2.431748      2.895621      7.412582
# min        1.000000      2.000000      1.000000      7.000000      1.000000
# 25%        5.000000      4.000000      2.000000      9.000000      9.000000
# 50%       10.000000      5.000000      2.000000     12.000000     15.000000
# 75%       15.000000      7.000000      2.000000     14.000000     21.000000
# max       20.000000     41.000000     39.000000     18.000000     30.000000
#
#            ...            CAGE_11         CAGED       melevel      religion  \
# count      ...       25192.000000  25192.000000  26018.000000  26018.000000
# mean       ...           2.987496    984.930970      1.822815      1.581098
# std        ...           1.427527   1017.925784      0.879074      0.568260
# min        ...           1.000000      0.000000      1.000000      1.000000
# 25%        ...           2.000000    417.000000      1.000000      1.000000
# 50%        ...           3.000000    909.000000      2.000000      2.000000
# 75%        ...           4.000000   1384.000000      3.000000      2.000000
# max        ...           5.000000   9999.000000      9.000000      9.000000
#
#                zone      chweight        wscore       windex5           PSU  \
# count  26018.000000  26018.000000  26018.000000  26018.000000  26018.000000
# mean       3.112845      0.968253     -0.107336      2.519217    765.843147
# std        1.603637      1.050827      0.968301      1.414660    429.034000
# min        1.000000      0.000000     -1.574326      0.000000      1.000000
# 25%        2.000000      0.430426     -0.950428      1.000000    394.000000
# 50%        3.000000      0.677064     -0.260526      2.000000    764.000000
# 75%        4.000000      1.161744      0.639379      4.000000   1138.000000
# max        6.000000     14.433318      3.008995      5.000000   1480.000000
#
#             stratum
# count  26018.000000
# mean      19.632601
# std       10.722314
# min        1.000000
# 25%       10.000000
# 50%       20.000000
# 75%       29.000000
# max       37.000000
#
# [8 rows x 209 columns]

# %%
columnNumbers = [x for x in range(ch_df.shape[1])]  # list of columns' integer indices

#columnNumbers.remove(0) #removing column integer index 0
ch_df = ch_df.iloc[:, columnNumbers] #return all columns except 0th column
ch_df.head()
# Out:
#    Unnamed: 0  HH1  HH2  LN  UF1  UF2  UF4  UF6  UF7  UF8D   ...     CAGE_11  \
# 0           1    1    4   6    1    4    6    2   15    21   ...         5.0
# 1           2    1    5   5    1    5    5    2   12    21   ...         3.0
# 2           3    1    5   6    1    5    6    2   12    21   ...         4.0
# 3           4    1    6   3    1    6    3    2   11    21   ...         1.0
# 4           5    1    7   4    1    7    4    2   16    21   ...         4.0
#
#     CAGED  melevel  religion  zone  chweight    wscore  windex5  PSU  stratum
# 0  1656.0        3         1     4  1.262202  1.653178        5    1        1
# 1  1031.0        2         1     4  1.262202  1.973658        5    1        1
# 2  1320.0        2         1     4  1.262202  1.973658        5    1        1
# 3   164.0        3         1     4  1.262202  1.964425        5    1        1
# 4  1162.0        3         1     4  1.262202  1.638443        5    1        1
#
# [5 rows x 293 columns]

# %%
wm_df = pd.read_csv('wm.csv', low_memory = False)

# %%
columnNumbers = [x for x in range(wm_df.shape[1])]  # list of columns' integer indices

#columnNumbers.remove(0) #removing column integer index 0
wm_df = wm_df.iloc[:, columnNumbers] #return all columns except 0th column
wm_df.head()
# Out:
#    Unnamed: 0  HH1  HH2  LN  WM1  WM2  WM4  WM5  WM6D  WM6M   ...     CSURV  \
# 0           1    1    1   3    1    1    3   16     4     3   ...       0.0
# 1           2    1    2   2    1    2    2    7     4     3   ...       0.0
# 2           3    1    3   2    1    3    2    7    21     2   ...       0.0
# 3           4    1    4   2    1    4    2   16    21     2   ...       4.0
# 4           5    1    6   2    1    6    2   11    21     2   ...       1.0
#
#    CDEAD  welevel  religion  zone  wmweight    wscore  windex5  PSU  stratum
# 0    0.0      3.0         1     4  1.199659  1.580774        5    1        1
# 1    0.0      3.0         1     4  1.199659  1.355768        5    1        1
# 2    0.0      3.0         1     4  1.199659  1.351060        5    1        1
# 3    0.0      3.0         1     4  1.199659  1.653178        5    1        1
# 4    1.0      3.0         1     4  1.199659  1.964425        5    1        1
#
# [5 rows x 255 columns]

# %%
ch_wm_df = ch_df.merge(wm_df, on = ['HH1','HH2'],suffixes = ('', '_y'))

# %%
ch_wm_df = ch_wm_df[ch_wm_df.columns.drop(list(ch_wm_df.filter(regex='_y')))]

# %%
ch_wm_df.head()
# Out:
#    Unnamed: 0  HH1  HH2  LN  UF1  UF2  UF4  UF6  UF7  UF8D    ...       WDOM  \
# 0           1    1    4   6    1    4    6    2   15    21    ...     1204.0
# 1           4    1    6   3    1    6    3    2   11    21    ...     1307.0
# 2           5    1    7   4    1    7    4    2   16    21    ...     1201.0
# 3           6    1    7   5    1    7    5    2   16    21    ...     1201.0
# 4           7    1    8   5    1    8    5    2   15    21    ...     1220.0
#
#    WAGEM  WDOBFC  WDOBLC  MSTATUS  CEB  CSURV  CDEAD  welevel  wmweight
# 0   27.0  1222.0  1280.0      1.0  4.0    4.0    0.0      3.0  1.199659
# 1   29.0  1329.0  1329.0      1.0  2.0    1.0    1.0      3.0  1.199659
# 2   22.0  1236.0  1320.0      1.0  3.0    3.0    0.0      3.0  1.199659
# 3   22.0  1236.0  1320.0      1.0  3.0    3.0    0.0      3.0  1.199659
# 4   26.0  1229.0  1289.0      1.0  3.0    3.0    0.0      3.0  1.199659
#
# [5 rows x 524 columns]

# %%
hh_df = pd.read_csv('hh.csv', low_memory = False)

# %%
columnNumbers = [x for x in range(hh_df.shape[1])]  # list of columns' integer indices

#columnNumbers.remove(0) #removing column integer index 0
hh_df = hh_df.iloc[:, columnNumbers] #return all columns except 0th column
hh_df.head()
# Out:
#    Unnamed: 0  HH1  HH2  HH3  HH4  HH5D  HH5M  HH5Y  HH6  HH7   ...     SI1  \
# 0           1    1    1   16    2     4     3  2011    1    1   ...     3.0
# 1           2    1    2    7    2     4     3  2011    1    1   ...     3.0
# 2           3    1    3    7    2    21     2  2011    1    1   ...     3.0
# 3           4    1    4   15    2    21     2  2011    1    1   ...     3.0
# 4           5    1    5   12    2    21     2  2011    1    1   ...     3.0
#
#    HHSEX  religion  zone  helevel  hhweight    wscore  windex5  PSU  stratum
# 0    1.0       1.0     4      3.0  1.250765  1.580774        5    1        1
# 1    2.0       1.0     4      1.0  1.250765  1.355768        5    1        1
# 2    2.0       1.0     4      2.0  1.250765  1.351060        5    1        1
# 3    1.0       1.0     4      3.0  1.250765  1.653178        5    1        1
# 4    1.0       1.0     4      2.0  1.250765  1.973658        5    1        1
#
# [5 rows x 132 columns]

# %%
df = ch_wm_df.merge(hh_df, on = ['HH1','HH2'],suffixes = ('', '_y'))

# %%
df = df[df.columns.drop(list(df.filter(regex='_y')))]

# %%
df.head()
# Out:
#    Unnamed: 0  HH1  HH2  LN  UF1  UF2  UF4  UF6  UF7  UF8D    ...     HW4  \
# 0           1    1    4   6    1    4    6    2   15    21    ...     2.0
# 1           4    1    6   3    1    6    3    2   11    21    ...     1.0
# 2           5    1    7   4    1    7    4    2   16    21    ...     2.0
# 3           6    1    7   5    1    7    5    2   16    21    ...     2.0
# 4           7    1    8   5    1    8    5    2   15    21    ...     2.0
#
#    HW5A  HW5B  HW5C  HW5D  HW5Y  SI1  HHSEX  helevel  hhweight
# 0   NaN   NaN   NaN   NaN   NaN  3.0    1.0      3.0  1.250765
# 1   NaN     B   NaN   NaN   NaN  3.0    1.0      3.0  1.250765
# 2   NaN   NaN   NaN   NaN   NaN  3.0    1.0      3.0  1.250765
# 3   NaN   NaN   NaN   NaN   NaN  3.0    1.0      3.0  1.250765
# 4   NaN   NaN   NaN   NaN   NaN  3.0    1.0      2.0  1.250765
#
# [5 rows x 645 columns]

# %% [markdown]
# Remove ID columns

# %%
df = df.loc[:, ~df.columns.str.startswith('UF')]
df = df.loc[:, ~df.columns.str.startswith('HH')]
df = df.loc[:, ~df.columns.str.startswith('LN')]
df.drop('AN1', axis=1, inplace=True)

# %%
df['IM1'].unique()
# Out:
# array([ 1.,  2.,  3., nan,  9.])

# %%
df['AG2'].unique()
# Out:
# array([ 4.,  0.,  3.,  1.,  2., nan])

# %%
#The vaccination module is usually applied for children up to 3 years old. 
#You should subset the dataset to that target group before running the models. 
#If you don’t then most of card not seen for the older children will be because of missing data. 
#Unfortunately this means that you will have less data to model.
df = df.loc[df['AG2'] <= 3]
len(df)
# Out:
# 30689

# %%
#Columns removed as per Unicef's feedback. 
#The sample weights (chweight, hhweight, etc) should not be used as features. 
#You can use weighted logistic regression if you want to incorporate the sample weight, 
#in this case just use the children sample weight. 
#Similarly, I would not use PSU and Stratum as features. 
#If you use the administrative division (e.g. region) as a features it should capture the stratum variable.

df = df.loc[:, ~df.columns.str.startswith('PSU')]
df = df.loc[:, ~df.columns.str.startswith('stratum')]

#Remove age columns
df = df.loc[:, ~df.columns.str.startswith('AG1D')]
df = df.loc[:, ~df.columns.str.startswith('AG2M')]
df = df.loc[:, ~df.columns.str.startswith('AG1Y')]
df = df.loc[:, ~df.columns.str.startswith('AG2')]
df = df.loc[:, ~df.columns.str.startswith('CAGE')]
df = df.loc[:, ~df.columns.str.startswith('CAGED')]
df = df.loc[:, ~df.columns.str.startswith('CAGE_6')]
df = df.loc[:, ~df.columns.str.startswith('CAGE_11')]

#Remove height columns
df = df.loc[:, ~df.columns.str.startswith('hhweight')]
df = df.loc[:, ~df.columns.str.startswith('HAZ')]
df = df.loc[:, ~df.columns.str.startswith('HAP')]
df = df.loc[:, ~df.columns.str.startswith('HAM')]
df = df.loc[:, ~df.columns.str.startswith('AN4')]

#Remove weight columns
df = df.loc[:, ~df.columns.str.startswith('WHM')]
df = df.loc[:, ~df.columns.str.startswith('WHZ')]
df = df.loc[:, ~df.columns.str.startswith('WHP')]
df = df.loc[:, ~df.columns.str.startswith('AN3')]
df = df.loc[:, ~df.columns.str.startswith('WAZ')]
df = df.loc[:, ~df.columns.str.startswith('WAM')]
#df = df.loc[:, ~df.columns.str.startswith('chweight')]

# %%
len(df)
# Out:
# 30689

# %%
#Set the target to column IM1 - Has the card and the card is seen
#Seperate the target column from the df.

df['card_seen'] = np.where(df['IM1'] == 1, 1,0)

# %%
df = df.loc[:, ~df.columns.str.startswith('IM')]

# %%
df = df.fillna(0)

# %%
target = df['card_seen']
target.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
#One hot encoding of categorical values using get_dummies function

dummies = pd.get_dummies(df)

# %%
y_cols=['card_seen']
X=dummies
y=dummies[y_cols]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y.values.ravel(), test_size=0.3, random_state=0)

# %% [markdown]
# # Handling data imbalance by downsampling the majority class in Training data

# %%
df_majority = X_train[X_train.card_seen == 0]
df_minority = X_train[X_train.card_seen == 1]

print(len(df_majority))
print(len(df_minority))

min_class_len = len(df_minority)
# Out:
# 16629
# 4853

# %%
# Downsample majority class
df_majority_downsampled = resample(df_majority, 
                                 replace= True,     # sample with replacement
                                 n_samples=min_class_len,    # to match majority class
                                 random_state=123) # reproducible results
 
# Combine majority class with downsampled minority class
df_downsampled = pd.concat([df_minority, df_majority_downsampled])
 
# Display new class counts
df_downsampled.card_seen.value_counts()
# Out:
# 1    4853
# 0    4853
# Name: card_seen, dtype: int64

# %%
X_train = df_downsampled
len(X_train)
# Out:
# 9706

# %%
y_train = X_train['card_seen']

# %%
X_train = X_train[X_train.columns.drop(list(X_train.filter(regex='card_seen')))]
X_test = X_test[X_test.columns.drop(list(X_test.filter(regex='card_seen')))]

# %% [markdown]
# # Logistic Regression Classifier

# %%
#Training the logistic regression model
logreg = LogisticRegression()
logreg.fit(X_train, y_train, sample_weight = X_train['chweight'])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
feature_importance = abs(logreg.coef_[0])
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5

# %%
len(feature_importance)
# Out:
# 828

# %%
feature_imp_data = list(zip(X_train, feature_importance))
feature_imp_data.sort(key=lambda x: x[1], reverse=True) 

# save the names and their respective scores separately
# reverse the tuples to go from most frequent to least frequent 
people = list(zip(*feature_imp_data))[0]
score = list(zip(*feature_imp_data))[1]

# %%
people = people[0:50] 
score = score[0:50] 
x_pos = np.arange(len(people))

# %%
# Read the Labels File into a df
labels_df = pd.read_csv('label_nig.csv',low_memory=False)
labels_df.head()
# Out:
#   name             label
# 0  HH1    Cluster number
# 1  HH2  Household number
# 2   LN       Line number
# 3  UF1    Cluster number
# 4  UF2  Household number

# %%
# Create a df with just the top 50 features
features_df = pd.DataFrame(feature_imp_data[0:50], columns=['name','Score'])
features_df
# Out:
#         name     Score
# 0        BR1  0.808364
# 1        MN5  0.473151
# 2   religion  0.296032
# 3       FLAG  0.285565
# 4        HA1  0.285178
# 5     CA6A_A  0.283480
# 6       CA4B  0.282944
# 7     CA6A_0  0.278308
# 8       CD14  0.261390
# 9     wscore  0.260149
# 10       FG3  0.249839
# 11      HC9B  0.246601
# 12     MN22A  0.232990
# 13   helevel  0.231710
# 14      HC8L  0.224372
# 15       BR2  0.219802
# 16      HC8J  0.219151
# 17      MN22  0.216208
# 18      HA15  0.205078
# 19      MN4B  0.201718
# 20      BF13  0.199843
# 21      MN24  0.196921
# 22      BF10  0.189731
# 23      HA17  0.188067
# 24   MN17H_H  0.186279
# 25       AN5  0.185182
# 26      HC9E  0.181154
# 27    ML6H_0  0.180793
# 28    ML6H_H  0.180761
# 29       WS9  0.180264
# 30    HW3D_D  0.177220
# 31    HW3C_0  0.176799
# 32      WAGE  0.175543
# 33    CP3D_D  0.172218
# 34    CP3D_0  0.172187
# 35    HW3D_0  0.170403
# 36    HW3C_C  0.169981
# 37      MN4D  0.169906
# 38    MN2B_B  0.169597
# 39      EC2A  0.168692
# 40       WS6  0.166405
# 41      EC11  0.165110
# 42    WS7B_B  0.161328
# 43   MN17H_0  0.161162
# 44    MN2B_0  0.159382
# 45    WS7B_0  0.158804
# 46   EC7DA_A  0.157965
# 47   EC7DA_0  0.156893
# 48   MN14A_A  0.155936
# 49   MN14A_0  0.155905

# %%
# Merge the feature file with the label file so that it can be used with an external dashboard
final_df = pd.merge(features_df,labels_df,on='name',how='left')
final_df.to_csv("Features_LR_Nig.csv", encoding='utf-8')
final_df.drop_duplicates(inplace= True)
final_df = final_df.reset_index(drop = True)
final_df
# Out:
#         name     Score                                              label
# 0        BR1  0.808364                                  Birth certificate
# 1        MN5  0.473151                                                NaN
# 2   religion  0.296032                                                NaN
# 3       FLAG  0.285565                 Flag for anthropometric indicators
# 4        HA1  0.285178                                                NaN
# 5     CA6A_A  0.283480                                                NaN
# 6       CA4B  0.282944               Pre-packaged ORS fluid for diarrhoea
# 7     CA6A_0  0.278308                                                NaN
# 8       CD14  0.261390                                                NaN
# 9     wscore  0.260149                              Combined wealth score
# 10       FG3  0.249839                                                NaN
# 11      HC9B  0.246601                                   Mobile telephone
# 12     MN22A  0.232990                                                NaN
# 13   helevel  0.231710                        Education of household head
# 14      HC8L  0.224372                                 Water lifting pump
# 15       BR2  0.219802                                   Birth registered
# 16      HC8J  0.219151                          Sewing / Knitting machine
# 17      MN22  0.216208                                                NaN
# 18      HA15  0.205078                                                NaN
# 19      MN4B  0.201718                                                NaN
# 20      BF13  0.199843                                                NaN
# 21      MN24  0.196921                                                NaN
# 22      BF10  0.189731                                                NaN
# 23      HA17  0.188067                                                NaN
# 24   MN17H_H  0.186279                                                NaN
# 25       AN5  0.185182                                                NaN
# 26      HC9E  0.181154                                  Animal-drawn cart
# 27    ML6H_0  0.180793                                                NaN
# 28    ML6H_H  0.180761                                                NaN
# 29       WS9  0.180264                             Toilet facility shared
# 30    HW3D_D  0.177220                                                NaN
# 31    HW3C_0  0.176799                                                NaN
# 32      WAGE  0.175543                                                NaN
# 33    CP3D_D  0.172218                                                NaN
# 34    CP3D_0  0.172187                                                NaN
# 35    HW3D_0  0.170403                                                NaN
# 36    HW3C_C  0.169981                                                NaN
# 37      MN4D  0.169906                                                NaN
# 38    MN2B_B  0.169597                                                NaN
# 39      EC2A  0.168692                                      Homemade toys
# 40       WS6  0.166405             Treat water to make safer for drinking
# 41      EC11  0.165110  Child able to pick up small object with 2 fingers
# 42    WS7B_B  0.161328                                                NaN
# 43   MN17H_0  0.161162                                                NaN
# 44    MN2B_0  0.159382                                                NaN
# 45    WS7B_0  0.158804                                                NaN
# 46   EC7DA_A  0.157965                                                NaN
# 47   EC7DA_0  0.156893                                                NaN
# 48   MN14A_A  0.155936                                                NaN
# 49   MN14A_0  0.155905                                                NaN

# %%
# calculate slope and intercept for the linear trend line
slope, intercept = np.polyfit(x_pos, score, 1)
trendline = intercept + (slope * x_pos)
plt.figure(figsize=(25,5))
plt.bar(x_pos, score,align='center')
plt.xticks(x_pos, people) 
plt.ylabel('Feature Importance')
plt.suptitle('Logistic Regression Feature Importance For Predicting If The Caregiver Has Card', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.74

# %%
#Overall classification report

print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.91      0.74      0.82      7139
#           1       0.45      0.74      0.56      2068
#
# avg / total       0.80      0.74      0.76      9207

# %% [markdown]
# # Random Forest Classifier

# %% [markdown]
# Random Forests is an ensemble model which uses a large number of strong decision trees through bagging.
# Each decision tree is built on a subset of features and a subset of rows from the data.
# The model combines all of them in order to smooth out their predictions

# %%
# Create a random forest Classifier. By convention, clf means 'Classifier'
rfc = RandomForestClassifier()

# Train the Classifier to take the training features and learn how they relate
# to the training y 
rfc.fit(X_train, y_train,sample_weight = X_train['chweight'])
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
y_pred = rfc.predict(X_test)
print('Accuracy of random forest classifier on test set: {:.2f}'.format(rfc.score(X_test, y_test)))
# Out:
# Accuracy of random forest classifier on test set: 0.76

# %%
#Overall classification report

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.92      0.75      0.83      7139
#           1       0.47      0.77      0.59      2068
#
# avg / total       0.82      0.76      0.77      9207

# %% [markdown]
# Let's validate the results of Random Forests Model with kfold cross validation

# %%
kfold = model_selection.KFold(n_splits=10, random_state=7)
scoring = 'accuracy'
results = model_selection.cross_val_score(rfc, X_train, y_train, cv=kfold, scoring=scoring)
print("10-fold cross validation average accuracy: %.3f" % (results.mean()))
# Out:
# 10-fold cross validation average accuracy: 0.728

# %%
feature_imp_data = list(zip(X_train, rfc.feature_importances_))

# %%
feature_imp_data.sort(key=lambda x: x[1], reverse=True) 

# save the names and their respective scores separately
# reverse the tuples to go from most frequent to least frequent 
people = list(zip(*feature_imp_data))[0]
score = list(zip(*feature_imp_data))[1]

# %%
# Create a df with just the top 50 features
features_df = pd.DataFrame(feature_imp_data[0:50], columns=['name','Score'])
features_df
# Out:
#           name     Score
# 0          WB5  0.034623
# 1          BR1  0.021528
# 2         HC1C  0.019715
# 3         MN19  0.015968
# 4         MN4B  0.015405
# 5         HA15  0.014461
# 6     religion  0.014062
# 7         HC1B  0.013798
# 8     chweight  0.012705
# 9         MN18  0.012073
# 10      wscore  0.011704
# 11        HC1A  0.011629
# 12     melevel  0.011588
# 13     helevel  0.010387
# 14  Unnamed: 0  0.009993
# 15    wmweight  0.009621
# 16         BMI  0.009318
# 17         WM1  0.008575
# 18        CDOB  0.008391
# 19         WAP  0.008315
# 20       WAGEM  0.008105
# 21        MA8Y  0.007693
# 22         BR3  0.007507
# 23         WM2  0.007011
# 24       HC14D  0.006852
# 25       WM10M  0.006671
# 26        ED4B  0.006649
# 27       WM11M  0.006608
# 28        WDOM  0.006588
# 29        WDOB  0.006573
# 30         CD9  0.006470
# 31        ZBMI  0.006059
# 32       CM12D  0.005987
# 33         MA2  0.005786
# 34         MA9  0.005745
# 35        AG1M  0.005604
# 36        WM6D  0.005602
# 37         WS8  0.005567
# 38        zone  0.005508
# 39         WS4  0.005405
# 40         WM9  0.005309
# 41        WS4B  0.005207
# 42       WS4AA  0.005143
# 43        WB1Y  0.004807
# 44        MN4A  0.004753
# 45        CM2D  0.004695
# 46         WB2  0.004660
# 47       WS4AB  0.004612
# 48      WDOBLC  0.004608
# 49         WS1  0.004590

# %%
# Merge the feature file with the label file so that it can be used with an external dashboard
final_df = pd.merge(features_df,labels_df,on='name',how='left')
final_df.to_csv("Features_RF_Nig.csv", encoding='utf-8')
final_df.drop_duplicates(inplace= True)
final_df = final_df.reset_index(drop = True)
final_df
# Out:
#           name     Score                                         label
# 0          WB5  0.034623                                           NaN
# 1          BR1  0.021528                             Birth certificate
# 2         HC1C  0.019715                                           NaN
# 3         MN19  0.015968                                           NaN
# 4         MN4B  0.015405                                           NaN
# 5         HA15  0.014461                                           NaN
# 6     religion  0.014062                                           NaN
# 7         HC1B  0.013798               Mother tongue of household head
# 8     chweight  0.012705                      Children's sample weight
# 9         MN18  0.012073                                           NaN
# 10      wscore  0.011704                         Combined wealth score
# 11        HC1A  0.011629                    Religion of household head
# 12     melevel  0.011588                            Mother's education
# 13     helevel  0.010387                   Education of household head
# 14  Unnamed: 0  0.009993                                           NaN
# 15    wmweight  0.009621                                           NaN
# 16         BMI  0.009318                           Body Mass Index WHO
# 17         WM1  0.008575                                           NaN
# 18        CDOB  0.008391                  Date of birth of child (CMC)
# 19         WAP  0.008315                Weight for age percentile NCHS
# 20       WAGEM  0.008105                                           NaN
# 21        MA8Y  0.007693                                           NaN
# 22         BR3  0.007507                    Know how to register birth
# 23         WM2  0.007011                                           NaN
# 24       HC14D  0.006852                                         Sheep
# 25       WM10M  0.006671                                           NaN
# 26        ED4B  0.006649         Highest grade completed at that level
# 27       WM11M  0.006608                                           NaN
# 28        WDOM  0.006588                                           NaN
# 29        WDOB  0.006573                                           NaN
# 30         CD9  0.006470                                           NaN
# 31        ZBMI  0.006059                   Body Mass Index z-score WHO
# 32       CM12D  0.005987                                           NaN
# 33         MA2  0.005786                                           NaN
# 34         MA9  0.005745                                           NaN
# 35        AG1M  0.005604                       Month of birth of child
# 36        WM6D  0.005602                                           NaN
# 37         WS8  0.005567                       Type of toilet facility
# 38        zone  0.005508                                           NaN
# 39         WS4  0.005405  Time (in minutes) to get water and come back
# 40         WM9  0.005309                                           NaN
# 41        WS4B  0.005207                                           NaN
# 42       WS4AA  0.005143                                           NaN
# 43        WB1Y  0.004807                                           NaN
# 44        MN4A  0.004753                                           NaN
# 45        CM2D  0.004695                                           NaN
# 46         WB2  0.004660                                           NaN
# 47       WS4AB  0.004612                                           NaN
# 48      WDOBLC  0.004608                                           NaN
# 49         WS1  0.004590                 Main source of drinking water

# %%
people = people[0:50]
score = score[0:50]
x_pos = np.arange(len(people))

# %%
# calculate slope and intercept for the linear trend line
slope, intercept = np.polyfit(x_pos, score, 1)
trendline = intercept + (slope * x_pos)
plt.figure(figsize=(25,5))
plt.bar(x_pos, score,align='center')
plt.xticks(x_pos, people) 
plt.ylabel('Feature Importance')
plt.suptitle('Random Forests Feature Importance For Predicting If The Caregiver Has Card', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
# calculate the fpr and tpr for all thresholds of the classification
probs = rfc.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.title('Receiver Operating Characteristic for Random Forests')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# # Gradient Boosting Decision Tree Classifier

# %% [markdown]
# Gradient Boosting Decision Trees is an ensemble model which uses a sequence of weak constrained decision trees through boosting.
# Each tree is allowed a maximum depth and hence tuned and each tree tries to correct the predictions of the trees before it.

# %%
gbd = GradientBoostingClassifier()
gbd = gbd.fit(X_train, y_train,sample_weight = X_train['chweight'])

# %%
y_pred = gbd.predict(X_test)
print('Accuracy of gradient boosting decision tree classifier on test set: {:.2f}'.format(gbd.score(X_test, y_test)))
# Out:
# Accuracy of gradient boosting decision tree classifier on test set: 0.76

# %%
kfold = model_selection.KFold(n_splits=10, random_state=1)
scoring = 'accuracy'
results = model_selection.cross_val_score(gbd, X_train, y_train, cv=kfold, scoring=scoring)
print("10-fold cross validation average accuracy: %.3f" % (results.mean()))
# Out:
# 10-fold cross validation average accuracy: 0.714

# %%
feature_imp_data = list(zip(X_train, gbd.feature_importances_))

# %%
feature_imp_data.sort(key=lambda x: x[1], reverse=True) 

# save the names and their respective scores separately
# reverse the tuples to go from most frequent to least frequent 
people = list(zip(*feature_imp_data))[0]
score = list(zip(*feature_imp_data))[1]

# %%
# Create a df with just the top 50 features
features_df = pd.DataFrame(feature_imp_data[0:100], columns=['name','Score'])
features_df
# Out:
#           name     Score
# 0         CDOB  0.079729
# 1          BR1  0.040369
# 2         HC1C  0.037752
# 3     chweight  0.029272
# 4   Unnamed: 0  0.028241
# 5          MN5  0.025442
# 6      melevel  0.017946
# 7         ED4B  0.017120
# 8          WS1  0.016608
# 9       wscore  0.016266
# 10         CD6  0.015689
# 11         WM1  0.015680
# 12         BR4  0.015575
# 13         WAP  0.014806
# 14      CA6A_A  0.014553
# 15         BMI  0.013974
# 16        ZBMI  0.013216
# 17       CM12D  0.012609
# 18     helevel  0.012530
# 19       CM12M  0.011864
# 20        CD14  0.011650
# 21         WB5  0.011001
# 22         WS6  0.010856
# 23        HC1A  0.010117
# 24        MN22  0.009594
# 25        zone  0.009464
# 26         HW4  0.009443
# 27        WB1Y  0.009427
# 28        HA15  0.009107
# 29       MN2AA  0.008983
# ..         ...       ...
# 70         MA9  0.004071
# 71        HC9B  0.003892
# 72    religion  0.003868
# 73        HA8B  0.003857
# 74        HC1B  0.003841
# 75        HC10  0.003838
# 76      ML6H_H  0.003821
# 77        HC9D  0.003803
# 78        EC10  0.003779
# 79       HC14E  0.003720
# 80        HA25  0.003719
# 81        BF10  0.003719
# 82        WDOB  0.003665
# 83        EC15  0.003648
# 84        AG1M  0.003624
# 85       WM11M  0.003567
# 86        EC3B  0.003395
# 87       UN13N  0.003351
# 88         WS2  0.003220
# 89        HC8M  0.003214
# 90         FG7  0.003112
# 91         FG5  0.003094
# 92       CM12Y  0.002908
# 93        HA18  0.002807
# 94       HC14G  0.002772
# 95         HA1  0.002763
# 96        HC12  0.002670
# 97        EC2B  0.002644
# 98         MN7  0.002578
# 99        DB3N  0.002535
#
# [100 rows x 2 columns]

# %%
# Merge the feature file with the label file so that it can be used with an external dashboard
final_df = pd.merge(features_df,labels_df,on='name',how='left')
final_df.to_csv("Features_GB_Nig.csv", encoding='utf-8')
final_df.drop_duplicates(inplace= True)
final_df = final_df.reset_index(drop = True)
final_df
# Out:
#           name     Score                                              label
# 0         CDOB  0.079729                       Date of birth of child (CMC)
# 1          BR1  0.040369                                  Birth certificate
# 2         HC1C  0.037752                                                NaN
# 3     chweight  0.029272                           Children's sample weight
# 4   Unnamed: 0  0.028241                                                NaN
# 5          MN5  0.025442                                                NaN
# 6      melevel  0.017946                                 Mother's education
# 7         ED4B  0.017120              Highest grade completed at that level
# 8          WS1  0.016608                      Main source of drinking water
# 9       wscore  0.016266                              Combined wealth score
# 10         CD6  0.015689                                                NaN
# 11         WM1  0.015680                                                NaN
# 12         BR4  0.015575  Main reason Child's Birth not registered with ...
# 13         WAP  0.014806                     Weight for age percentile NCHS
# 14      CA6A_A  0.014553                                                NaN
# 15         BMI  0.013974                                Body Mass Index WHO
# 16        ZBMI  0.013216                        Body Mass Index z-score WHO
# 17       CM12D  0.012609                                                NaN
# 18     helevel  0.012530                        Education of household head
# 19       CM12M  0.011864                                                NaN
# 20        CD14  0.011650                                                NaN
# 21         WB5  0.011001                                                NaN
# 22         WS6  0.010856             Treat water to make safer for drinking
# 23        HC1A  0.010117                         Religion of household head
# 24        MN22  0.009594                                                NaN
# 25        zone  0.009464                                                NaN
# 26         HW4  0.009443    Soap/other material available for washing hands
# 27        WB1Y  0.009427                                                NaN
# 28        HA15  0.009107                                                NaN
# 29       MN2AA  0.008983                                                NaN
# ..         ...       ...                                                ...
# 70         MA9  0.004071                                                NaN
# 71        HC9B  0.003892                                   Mobile telephone
# 72    religion  0.003868                                                NaN
# 73        HA8B  0.003857                                                NaN
# 74        HC1B  0.003841                    Mother tongue of household head
# 75        HC10  0.003838                        Household owns the dwelling
# 76      ML6H_H  0.003821                                                NaN
# 77        HC9D  0.003803                               Motorcycle / scooter
# 78        EC10  0.003779  Child knows name and recognizes symbol of all ...
# 79       HC14E  0.003720                                           Chickens
# 80        HA25  0.003719                                                NaN
# 81        BF10  0.003719                                                NaN
# 82        WDOB  0.003665                                                NaN
# 83        EC15  0.003648          Child gets along well with other children
# 84        AG1M  0.003624                            Month of birth of child
# 85       WM11M  0.003567                                                NaN
# 86        EC3B  0.003395  In past week, days left with other child for m...
# 87       UN13N  0.003351                                                NaN
# 88         WS2  0.003220       Main source of water used for other purposes
# 89        HC8M  0.003214                                               Iron
# 90         FG7  0.003112                                                NaN
# 91         FG5  0.003094                                                NaN
# 92       CM12Y  0.002908                                                NaN
# 93        HA18  0.002807                                                NaN
# 94       HC14G  0.002772                                                NaN
# 95         HA1  0.002763                                                NaN
# 96        HC12  0.002670  Acres of agricultural land members of househol...
# 97        EC2B  0.002644                                    Toys from shops
# 98         MN7  0.002578                                                NaN
# 99        DB3N  0.002535                                                NaN
#
# [100 rows x 3 columns]

# %%
people = people[0:30]
score = score[0:30]
x_pos = np.arange(len(people))

# %%
#Overall classification report

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.92      0.76      0.83      7139
#           1       0.49      0.78      0.60      2068
#
# avg / total       0.82      0.76      0.78      9207

# %%
# calculate slope and intercept for the linear trend line
slope, intercept = np.polyfit(x_pos, score, 1)
trendline = intercept + (slope * x_pos)
plt.figure(figsize=(25,5))
plt.bar(x_pos, score,align='center')
plt.xticks(x_pos, people) 
plt.ylabel('Feature Importance')
plt.suptitle('Gradient Boosting Decision Trees Feature Importance For Predicting If The Caregiver Has Card', fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.xticks(rotation=90)
plt.show()

# %%
# calculate the fpr and tpr for all thresholds of the classification
probs = gbd.predict_proba(X_test)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

# method I: plt
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.title('Receiver Operating Characteristic for Gradient Boosting Decision Trees')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
print(final_df.head())
nan_df = final_df[final_df.label.isnull()]
len(nan_df)
# Out:
#          name     Score                         label
# 0        CDOB  0.079729  Date of birth of child (CMC)
# 1         BR1  0.040369             Birth certificate
# 2        HC1C  0.037752                           NaN
# 3    chweight  0.029272      Children's sample weight
# 4  Unnamed: 0  0.028241                           NaN
# 58

# %%
f_name_lst = list(nan_df.name)

# %%
final_df = final_df[~final_df['name'].isin(f_name_lst)]

# %%
final_df.sort_values('Score')
# Out:
#         name     Score                                              label
# 97      EC2B  0.002644                                    Toys from shops
# 96      HC12  0.002670  Acres of agricultural land members of househol...
# 89      HC8M  0.003214                                               Iron
# 88       WS2  0.003220       Main source of water used for other purposes
# 86      EC3B  0.003395  In past week, days left with other child for m...
# 84      AG1M  0.003624                            Month of birth of child
# 83      EC15  0.003648          Child gets along well with other children
# 79     HC14E  0.003720                                           Chickens
# 78      EC10  0.003779  Child knows name and recognizes symbol of all ...
# 77      HC9D  0.003803                               Motorcycle / scooter
# 75      HC10  0.003838                        Household owns the dwelling
# 74      HC1B  0.003841                    Mother tongue of household head
# 71      HC9B  0.003892                                   Mobile telephone
# 66      HC8J  0.004427                          Sewing / Knitting machine
# 65       EC1  0.004432  Number of children's books or picture books fo...
# 64       TN1  0.004725                        Household has mosquito nets
# 62     HC14A  0.004915              Cattle, milk cows, buffaloes or bulls
# 59    TN12_1  0.004988                       Person 1 who slept under net
# 57       WS8  0.005060                            Type of toilet facility
# 56      HC8E  0.005098                                       Refrigerator
# 52      WS11  0.005447              Households using this toilet facility
# 46       HC6  0.005686                     Type of fuel using for cooking
# 43       HC4  0.006069                              Main material of roof
# 38    TN12_2  0.006860                       Person 2 who slept under net
# 37       HC5  0.007028                     Main material of exterior wall
# 34       TN2  0.007940                            Number of mosquito nets
# 32       HC3  0.008098                             Main material of floor
# 26       HW4  0.009443    Soap/other material available for washing hands
# 23      HC1A  0.010117                         Religion of household head
# 22       WS6  0.010856             Treat water to make safer for drinking
# 18   helevel  0.012530                        Education of household head
# 16      ZBMI  0.013216                        Body Mass Index z-score WHO
# 15       BMI  0.013974                                Body Mass Index WHO
# 13       WAP  0.014806                     Weight for age percentile NCHS
# 12       BR4  0.015575  Main reason Child's Birth not registered with ...
# 9     wscore  0.016266                              Combined wealth score
# 8        WS1  0.016608                      Main source of drinking water
# 7       ED4B  0.017120              Highest grade completed at that level
# 6    melevel  0.017946                                 Mother's education
# 3   chweight  0.029272                           Children's sample weight
# 1        BR1  0.040369                                  Birth certificate
# 0       CDOB  0.079729                       Date of birth of child (CMC)

# %%
selected_features = list(final_df.name)
X_train = X_train[selected_features]
X_test = X_test[selected_features]

# %%
#Training the logistic regression model
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_pred = logreg.predict(X_test)
print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of logistic regression classifier on test set: 0.71

# %%
feature_importance = (logreg.coef_[0])
feature_importance = (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .5

# %%
col_list = list(X_train.columns[sorted_idx])
label_list = []
for i in col_list:
    label_row = final_df[final_df['name'] == i]
    label_list.append(list(label_row.label))

label_list = [''.join(x) for x in label_list]
print(label_list)
# Out:
# ['Birth certificate', 'Child knows name and recognizes symbol of all numbers from 1-10', 'Mobile telephone', 'Religion of household head', 'Sewing / Knitting machine', 'Household has mosquito nets', 'Treat water to make safer for drinking', "Number of children's books or picture books for child", "Children's sample weight", 'Toys from shops', 'Number of mosquito nets', 'Main material of roof', 'Body Mass Index z-score WHO', 'Main material of exterior wall', 'Type of fuel using for cooking', 'Cattle, milk cows, buffaloes or bulls', 'Households using this toilet facility', 'Acres of agricultural land members of household owns', 'Body Mass Index WHO', 'Month of birth of child', 'Main source of water used for other purposes', 'Weight for age percentile NCHS', 'Date of birth of child (CMC)', 'Chickens', 'Type of toilet facility', 'Person 2 who slept under net', 'Main source of drinking water', 'Mother tongue of household head', 'Main material of floor', 'Highest grade completed at that level', 'Child gets along well with other children', 'Person 1 who slept under net', 'In past week, days left with other child for more than 1 hour', 'Motorcycle / scooter', 'Soap/other material available for washing hands', 'Household owns the dwelling', "Main reason Child's Birth not registered with Local Government Department (UC)", 'Refrigerator', "Mother's education", 'Education of household head', 'Combined wealth score', 'Iron']

# %%
result_df = pd.DataFrame({'Feature': label_list ,'Coefficient': feature_importance[sorted_idx],'Column' :col_list})
result_df.head()
# Out:
#    Coefficient Column                                            Feature
# 0    -2.465658    BR1                                  Birth certificate
# 1    -1.068734   EC10  Child knows name and recognizes symbol of all ...
# 2    -0.915152   HC9B                                   Mobile telephone
# 3    -0.704173   HC1A                         Religion of household head
# 4    -0.635668   HC8J                          Sewing / Knitting machine

# %%
result_df.to_csv('result_Nigeria.csv')

# %%
featfig = plt.figure(figsize=(20,30))
featax = featfig.add_subplot(1, 1, 1)
featax.barh(pos, feature_importance[sorted_idx], align='center')
featax.set_yticks(pos)
featax.set_yticklabels(label_list, fontsize=8)
featax.set_xlabel('Relative Feature Importance')
plt.tick_params(axis='both', which='major', labelsize=15)
plt.tick_params(axis='both', which='minor', labelsize=15)
plt.title('Logistic Regression Feature Importance For Predicting Pass/Fail', fontsize=20)
plt.tight_layout()   
plt.show()
